# %% [markdown]
# ### differents $B_\theta$, petits $\theta$, differents $Bsf$

# %%
# %run 30_testing_different_bandwidths.ipynb
# Out:
# data_folder = ../Psychopy_data/pilot/B_theta_B_sf
# Overwriting tmp/30_testing_different_bandwidths.py
#
#  Initializing
# B_thetas =  [0.09817477 0.18005332 0.33021925 0.60562477 1.11072073]
# B_sfs =  [0.0625 0.125  0.25   0.5    1.    ]

# %%
# !ipython tmp/30_testing_different_bandwidths.py {data_folder} 5 5 20 LP
# Out:
#  Initializing
# B_thetas =  [0.09817477 0.18005332 0.33021925 0.60562477 1.11072073]
# B_sfs =  [0.0625 0.125  0.25   0.5    1.    ]
# pygame 1.9.6
# Hello from the pygame community. https://www.pygame.org/contribute.html
# 2020-05-12 22:09:40.755 Python[23819:5184265] ApplePersistenceIgnoreState: Existing state will not be touched. New state will be written to (null)
# Test started
# At trial  0 Angle= 22.500 answer is  right (correct= True );
# At trial  1 Angle= -13.026 answer is  left (correct= True );
# At trial  2 Angle= -3.553 answer is  left (correct= True );
# At trial  3 Angle= 10.658 answer is  right (correct= True );
# At trial  4 Angle= 15.395 answer is  left (correct= False );
# At trial  5 Angle= 1.184 answer is  right (correct= True );
# At trial  6 Angle= 22.500 answer is  right (correct= True );
# At trial  7 Angle= 13.026 answer is  right (correct= True );
# At trial  8 Angle= 22.500 answer is  right (correct= True );
# ...
