# %% [markdown]
# ### differents $B_\theta$, petits $\theta$, differents $Bsf$

# %%
# %run 20_testing_different_bandwidths.ipynb
# Out:
# data_folder = ../Psychopy_data/pilot/B_theta
# Overwriting tmp/20_testing_different_bandwidths.py
#
#  Initializing
# B_thetas =  [0.06981317 0.13962634 0.20943951 0.27925268 0.34906585 0.41887902
#  0.48869219 0.55850536 0.62831853 0.6981317  0.76794487 0.83775804
#  0.90757121 0.97738438 1.04719755]
# B_sfs =  [0.5]

# %%
# !ipython tmp/20_testing_different_bandwidths.py {data_folder} 15 1 20 LP
# Out:
#  Initializing
# B_thetas =  [0.06981317 0.13962634 0.20943951 0.27925268 0.34906585 0.41887902
#  0.48869219 0.55850536 0.62831853 0.6981317  0.76794487 0.83775804
#  0.90757121 0.97738438 1.04719755]
# B_sfs =  [0.5]
# pygame 1.9.6
# Hello from the pygame community. https://www.pygame.org/contribute.html
# 2020-05-12 16:14:52.735 Python[20580:5085093] ApplePersistenceIgnoreState: Existing state will not be touched. New state will be written to (null)
# Test started
# At trial  0 Angle= -3.553 answer is  right (correct= False );
# At trial  1 Angle= 5.921 answer is  right (correct= True );
# At trial  2 Angle= -10.658 answer is  left (correct= True );
# At trial  3 Angle= -13.026 answer is  left (correct= True );
# At trial  4 Angle= 13.026 answer is  right (correct= True );
# At trial  5 Angle= -15.395 answer is  left (correct= True );
# At trial  6 Angle= 1.184 answer is  right (correct= True );
# At trial  7 Angle= 10.658 answer is  left (correct= False );
# At trial  8 Angle= -5.921 answer is  right (correct= False );
# At trial  9 Angle= 8.289 answer is  right (correct= True );
# At trial  10 Angle= 10.658 answer is  right (correct= True );
# At trial  11 Angle= 1.184 answer is  left (correct= False );
# At trial  12 Angle= -13.026 answer is  left (correct= True );
# At trial  13 Angle= -15.395 answer is  left (correct= True );
# At trial  14 Angle= -17.763 answer is  left (correct= True );
# At trial  15 Angle= 5.921 answer is  right (correct= True );
# At trial  16 Angle= 20.132 answer is  right (correct= True );
# At trial  17 Angle= -20.132 answer is  left (correct= True );
# At trial  18 Angle= -3.553 answer is  left (correct= True );
# At trial  19 Angle= -17.763 answer is  left (correct= True );
# At trial  20 Angle= 5.921 answer is  right (correct= True );
# At trial  21 Angle= 17.763 answer is  right (correct= True );
# At trial  22 Angle= 20.132 answer is  right (correct= True );
# At trial  23 Angle= -15.395 answer is  left (correct= True );
# At trial  24 Angle= 17.763 answer is  right (correct= True );
# At trial  25 Angle= 8.289 answer is  right (correct= True );
# At trial  26 Angle= 3.553 answer is  right (correct= True );
# At trial  27 Angle= -10.658 answer is  left (correct= True );
# At trial  28 Angle= 20.132 answer is  right (correct= True );
# At trial  29 Angle= 5.921 answer is  right (correct= True );
# At trial  30 Angle= 1.184 answer is  left (correct= False );
# At trial  31 Angle= 5.921 answer is  right (correct= True );
# At trial  32 Angle= 15.395 answer is  right (correct= True );
# At trial  33 Angle= 3.553 answer is  right (correct= True );
# At trial  34 Angle= 20.132 answer is  right (correct= True );
# At trial  35 Angle= 1.184 answer is  right (correct= True );
# At trial  36 Angle= 1.184 answer is  left (correct= False );
# At trial  37 Angle= 1.184 answer is  right (correct= True );
# At trial  38 Angle= -20.132 answer is  left (correct= True );
# At trial  39 Angle= 8.289 answer is  right (correct= True );
# At trial  40 Angle= -1.184 answer is  right (correct= False );
# At trial  41 Angle= -3.553 answer is  left (correct= True );
# At trial  42 Angle= -22.500 answer is  left (correct= True );
# At trial  43 Angle= -1.184 answer is  left (correct= True );
# At trial  44 Angle= -20.132 answer is  left (correct= True );
# At trial  45 Angle= -20.132 answer is  left (correct= True );
# At trial  46 Angle= -3.553 answer is  left (correct= True );
# At trial  47 Angle= -20.132 answer is  left (correct= True );
# At trial  48 Angle= -15.395 answer is  left (correct= True );
# At trial  49 Angle= 5.921 answer is  right (correct= True );
# At trial  50 Angle= -10.658 answer is  left (correct= True );
# At trial  51 Angle= 13.026 answer is  right (correct= True );
# At trial  52 Angle= 17.763 answer is  right (correct= True );
# At trial  53 Angle= -15.395 answer is  left (correct= True );
# At trial  54 Angle= -8.289 answer is  left (correct= True );
# At trial  55 Angle= -15.395 answer is  left (correct= True );
# At trial  56 Angle= -22.500 answer is  left (correct= True );
# At trial  57 Angle= 17.763 answer is  right (correct= True );
# At trial  58 Angle= 5.921 answer is  right (correct= True );
# At trial  59 Angle= 17.763 answer is  right (correct= True );
# At trial  60 Angle= -15.395 answer is  left (correct= True );
# At trial  61 Angle= -1.184 answer is  left (correct= True );
# At trial  62 Angle= -3.553 answer is  left (correct= True );
# At trial  63 Angle= -1.184 answer is  right (correct= False );
# At trial  64 Angle= -13.026 answer is  left (correct= True );
# At trial  65 Angle= -22.500 answer is  left (correct= True );
# At trial  66 Angle= -22.500 answer is  left (correct= True );
# At trial  67 Angle= -13.026 answer is  left (correct= True );
# At trial  68 Angle= -3.553 answer is  left (correct= True );
# At trial  69 Angle= -10.658 answer is  left (correct= True );
# At trial  70 Angle= -10.658 answer is  left (correct= True );
# At trial  71 Angle= 13.026 answer is  right (correct= True );
# At trial  72 Angle= -10.658 answer is  left (correct= True );
# At trial  73 Angle= 3.553 answer is  right (correct= True );
# At trial  74 Angle= 13.026 answer is  right (correct= True );
# At trial  75 Angle= 3.553 answer is  right (correct= True );
# At trial  76 Angle= -15.395 answer is  left (correct= True );
# At trial  77 Angle= 5.921 answer is  left (correct= False );
# At trial  78 Angle= -15.395 answer is  left (correct= True );
# At trial  79 Angle= -13.026 answer is  left (correct= True );
# At trial  80 Angle= -8.289 answer is  left (correct= True );
# At trial  81 Angle= -5.921 answer is  left (correct= True );
# At trial  82 Angle= -22.500 answer is  left (correct= True );
# At trial  83 Angle= -10.658 answer is  left (correct= True );
# At trial  84 Angle= -8.289 answer is  left (correct= True );
# At trial  85 Angle= 13.026 answer is  right (correct= True );
# At trial  86 Angle= -20.132 answer is  left (correct= True );
# At trial  87 Angle= -3.553 answer is  left (correct= True );
# At trial  88 Angle= 1.184 answer is  right (correct= True );
# At trial  89 Angle= 10.658 answer is  left (correct= False );
# At trial  90 Angle= -17.763 answer is  left (correct= True );
# At trial  91 Angle= 1.184 answer is  right (correct= True );
# At trial  92 Angle= -8.289 answer is  left (correct= True );
# At trial  93 Angle= 13.026 answer is  right (correct= True );
# At trial  94 Angle= 5.921 answer is  right (correct= True );
# At trial  95 Angle= 15.395 answer is  right (correct= True );
# At trial  96 Angle= -3.553 answer is  right (correct= False );
# At trial  97 Angle= 8.289 answer is  right (correct= True );
# At trial  98 Angle= -10.658 answer is  left (correct= True );
# At trial  99 Angle= -20.132 answer is  left (correct= True );
# At trial  100 Angle= -20.132 answer is  left (correct= True );
# At trial  101 Angle= -22.500 answer is  left (correct= True );
# At trial  102 Angle= -1.184 answer is  left (correct= True );
# At trial  103 Angle= -17.763 answer is  left (correct= True );
# At trial  104 Angle= -8.289 answer is  left (correct= True );
# At trial  105 Angle= -15.395 answer is  left (correct= True );
# At trial  106 Angle= 3.553 answer is  right (correct= True );
# At trial  107 Angle= -20.132 answer is  left (correct= True );
# At trial  108 Angle= -17.763 answer is  left (correct= True );
# At trial  109 Angle= -13.026 answer is  left (correct= True );
# At trial  110 Angle= 10.658 answer is  right (correct= True );
# At trial  111 Angle= -22.500 answer is  left (correct= True );
# At trial  112 Angle= 22.500 answer is  right (correct= True );
# At trial  113 Angle= -17.763 answer is  left (correct= True );
# At trial  114 Angle= -3.553 answer is  left (correct= True );
# At trial  115 Angle= -3.553 answer is  left (correct= True );
# At trial  116 Angle= 17.763 answer is  right (correct= True );
# At trial  117 Angle= -8.289 answer is  left (correct= True );
# At trial  118 Angle= -8.289 answer is  left (correct= True );
# At trial  119 Angle= 15.395 answer is  right (correct= True );
# At trial  120 Angle= -15.395 answer is  right (correct= False );
# At trial  121 Angle= -13.026 answer is  left (correct= True );
# At trial  122 Angle= 10.658 answer is  left (correct= False );
# At trial  123 Angle= 13.026 answer is  right (correct= True );
# At trial  124 Angle= -17.763 answer is  left (correct= True );
# At trial  125 Angle= -5.921 answer is  left (correct= True );
# At trial  126 Angle= 15.395 answer is  right (correct= True );
# At trial  127 Angle= 8.289 answer is  left (correct= False );
# At trial  128 Angle= -20.132 answer is  left (correct= True );
# At trial  129 Angle= 22.500 answer is  right (correct= True );
# At trial  130 Angle= -8.289 answer is  right (correct= False );
# At trial  131 Angle= -22.500 answer is  left (correct= True );
# At trial  132 Angle= 5.921 answer is  right (correct= True );
# At trial  133 Angle= 10.658 answer is  right (correct= True );
# At trial  134 Angle= 3.553 answer is  right (correct= True );
# At trial  135 Angle= 13.026 answer is  right (correct= True );
# At trial  136 Angle= 8.289 answer is  right (correct= True );
# At trial  137 Angle= 3.553 answer is  right (correct= True );
# At trial  138 Angle= -20.132 answer is  left (correct= True );
# At trial  139 Angle= 20.132 answer is  left (correct= False );
# At trial  140 Angle= 20.132 answer is  left (correct= False );
# At trial  141 Angle= 3.553 answer is  left (correct= False );
# At trial  142 Angle= 22.500 answer is  right (correct= True );
# At trial  143 Angle= -3.553 answer is  right (correct= False );
# At trial  144 Angle= 22.500 answer is  right (correct= True );
# At trial  145 Angle= -5.921 answer is  left (correct= True );
# At trial  146 Angle= -1.184 answer is  right (correct= False );
# At trial  147 Angle= -1.184 answer is  right (correct= False );
# At trial  148 Angle= -20.132 answer is  left (correct= True );
# At trial  149 Angle= -22.500 answer is  right (correct= False );
# At trial  150 Angle= 20.132 answer is  left (correct= False );
# At trial  151 Angle= 15.395 answer is  right (correct= True );
# At trial  152 Angle= -15.395 answer is  left (correct= True );
# At trial  153 Angle= -5.921 answer is  right (correct= False );
# At trial  154 Angle= 17.763 answer is  right (correct= True );
# At trial  155 Angle= 10.658 answer is  right (correct= True );
# At trial  156 Angle= 8.289 answer is  right (correct= True );
# At trial  157 Angle= -13.026 answer is  right (correct= False );
# At trial  158 Angle= -10.658 answer is  left (correct= True );
# At trial  159 Angle= -1.184 answer is  right (correct= False );
# At trial  160 Angle= -5.921 answer is  right (correct= False );
# At trial  161 Angle= 10.658 answer is  right (correct= True );
# At trial  162 Angle= -13.026 answer is  left (correct= True );
# At trial  163 Angle= -1.184 answer is  left (correct= True );
# At trial  164 Angle= -13.026 answer is  left (correct= True );
# At trial  165 Angle= -1.184 answer is  right (correct= False );
# At trial  166 Angle= -1.184 answer is  right (correct= False );
# At trial  167 Angle= 13.026 answer is  right (correct= True );
# At trial  168 Angle= 20.132 answer is  right (correct= True );
# At trial  169 Angle= 20.132 answer is  right (correct= True );
# At trial  170 Angle= 17.763 answer is  right (correct= True );
# At trial  171 Angle= -17.763 answer is  left (correct= True );
# At trial  172 Angle= 22.500 answer is  right (correct= True );
# At trial  173 Angle= -5.921 answer is  left (correct= True );
# At trial  174 Angle= 3.553 answer is  right (correct= True );
# At trial  175 Angle= -22.500 answer is  left (correct= True );
# At trial  176 Angle= 8.289 answer is  right (correct= True );
# At trial  177 Angle= 13.026 answer is  right (correct= True );
# At trial  178 Angle= 15.395 answer is  right (correct= True );
# At trial  179 Angle= 22.500 answer is  right (correct= True );
# At trial  180 Angle= 22.500 answer is  right (correct= True );
# At trial  181 Angle= 20.132 answer is  right (correct= True );
# At trial  182 Angle= 15.395 answer is  right (correct= True );
# At trial  183 Angle= -5.921 answer is  left (correct= True );
# At trial  184 Angle= -10.658 answer is  left (correct= True );
# At trial  185 Angle= -5.921 answer is  right (correct= False );
# At trial  186 Angle= -8.289 answer is  left (correct= True );
# At trial  187 Angle= -10.658 answer is  left (correct= True );
# At trial  188 Angle= 10.658 answer is  right (correct= True );
# At trial  189 Angle= 15.395 answer is  right (correct= True );
# At trial  190 Angle= -1.184 answer is  right (correct= False );
# At trial  191 Angle= 15.395 answer is  right (correct= True );
# At trial  192 Angle= 15.395 answer is  right (correct= True );
# At trial  193 Angle= 8.289 answer is  right (correct= True );
# At trial  194 Angle= 1.184 answer is  right (correct= True );
# At trial  195 Angle= 17.763 answer is  right (correct= True );
# At trial  196 Angle= 10.658 answer is  right (correct= True );
# At trial  197 Angle= 13.026 answer is  right (correct= True );
# At trial  198 Angle= 15.395 answer is  right (correct= True );
# At trial  199 Angle= -13.026 answer is  right (correct= False );
# At trial  200 Angle= 17.763 answer is  left (correct= False );
# At trial  201 Angle= -17.763 answer is  right (correct= False );
# At trial  202 Angle= 8.289 answer is  right (correct= True );
# At trial  203 Angle= 1.184 answer is  right (correct= True );
# At trial  204 Angle= -13.026 answer is  left (correct= True );
# At trial  205 Angle= -8.289 answer is  left (correct= True );
# At trial  206 Angle= -10.658 answer is  left (correct= True );
# At trial  207 Angle= -13.026 answer is  left (correct= True );
# At trial  208 Angle= -5.921 answer is  right (correct= False );
# At trial  209 Angle= -5.921 answer is  left (correct= True );
# At trial  210 Angle= 3.553 answer is  left (correct= False );
# At trial  211 Angle= -15.395 answer is  left (correct= True );
# At trial  212 Angle= 17.763 answer is  right (correct= True );
# At trial  213 Angle= 3.553 answer is  left (correct= False );
# At trial  214 Angle= 5.921 answer is  right (correct= True );
# At trial  215 Angle= -22.500 answer is  left (correct= True );
# At trial  216 Angle= 22.500 answer is  right (correct= True );
# At trial  217 Angle= -8.289 answer is  left (correct= True );
# At trial  218 Angle= 20.132 answer is  right (correct= True );
# At trial  219 Angle= 22.500 answer is  right (correct= True );
# At trial  220 Angle= -5.921 answer is  right (correct= False );
# At trial  221 Angle= -5.921 answer is  left (correct= True );
# At trial  222 Angle= -20.132 answer is  left (correct= True );
# At trial  223 Angle= -8.289 answer is  left (correct= True );
# At trial  224 Angle= -3.553 answer is  right (correct= False );
# At trial  225 Angle= 15.395 answer is  right (correct= True );
# At trial  226 Angle= 17.763 answer is  right (correct= True );
# At trial  227 Angle= 10.658 answer is  right (correct= True );
# At trial  228 Angle= 1.184 answer is  left (correct= False );
# At trial  229 Angle= 10.658 answer is  right (correct= True );
# At trial  230 Angle= 13.026 answer is  right (correct= True );
# At trial  231 Angle= -1.184 answer is  left (correct= True );
# At trial  232 Angle= 17.763 answer is  right (correct= True );
# At trial  233 Angle= -5.921 answer is  right (correct= False );
# At trial  234 Angle= 17.763 answer is  right (correct= True );
# At trial  235 Angle= 8.289 answer is  right (correct= True );
# At trial  236 Angle= -15.395 answer is  left (correct= True );
# At trial  237 Angle= -13.026 answer is  left (correct= True );
# At trial  238 Angle= 8.289 answer is  right (correct= True );
# At trial  239 Angle= -8.289 answer is  right (correct= False );
# At trial  240 Angle= -3.553 answer is  left (correct= True );
# At trial  241 Angle= 10.658 answer is  right (correct= True );
# At trial  242 Angle= -8.289 answer is  left (correct= True );
# At trial  243 Angle= -17.763 answer is  left (correct= True );
# At trial  244 Angle= 5.921 answer is  left (correct= False );
# At trial  245 Angle= 1.184 answer is  right (correct= True );
# At trial  246 Angle= 22.500 answer is  right (correct= True );
# At trial  247 Angle= -13.026 answer is  left (correct= True );
# At trial  248 Angle= 22.500 answer is  right (correct= True );
# At trial  249 Angle= 1.184 answer is  right (correct= True );
# At trial  250 Angle= 22.500 answer is  left (correct= False );
# At trial  251 Angle= 3.553 answer is  right (correct= True );
# At trial  252 Angle= 20.132 answer is  right (correct= True );
# At trial  253 Angle= 8.289 answer is  right (correct= True );
# At trial  254 Angle= -15.395 answer is  left (correct= True );
# At trial  255 Angle= -17.763 answer is  right (correct= False );
# At trial  256 Angle= 5.921 answer is  left (correct= False );
# At trial  257 Angle= -17.763 answer is  left (correct= True );
# At trial  258 Angle= -22.500 answer is  right (correct= False );
# At trial  259 Angle= -22.500 answer is  left (correct= True );
# At trial  260 Angle= 8.289 answer is  right (correct= True );
# At trial  261 Angle= -10.658 answer is  left (correct= True );
# At trial  262 Angle= -20.132 answer is  left (correct= True );
# At trial  263 Angle= 5.921 answer is  right (correct= True );
# At trial  264 Angle= -17.763 answer is  left (correct= True );
# At trial  265 Angle= -5.921 answer is  right (correct= False );
# At trial  266 Angle= -22.500 answer is  left (correct= True );
# At trial  267 Angle= 13.026 answer is  left (correct= False );
# At trial  268 Angle= 20.132 answer is  right (correct= True );
# At trial  269 Angle= 10.658 answer is  right (correct= True );
# At trial  270 Angle= 15.395 answer is  right (correct= True );
# At trial  271 Angle= -1.184 answer is  left (correct= True );
# At trial  272 Angle= 1.184 answer is  right (correct= True );
# At trial  273 Angle= -8.289 answer is  left (correct= True );
# At trial  274 Angle= -17.763 answer is  right (correct= False );
# At trial  275 Angle= 1.184 answer is  right (correct= True );
# At trial  276 Angle= -1.184 answer is  left (correct= True );
# At trial  277 Angle= -20.132 answer is  left (correct= True );
# At trial  278 Angle= -17.763 answer is  left (correct= True );
# At trial  279 Angle= 22.500 answer is  right (correct= True );
# At trial  280 Angle= 8.289 answer is  right (correct= True );
# At trial  281 Angle= 15.395 answer is  right (correct= True );
# At trial  282 Angle= -3.553 answer is  right (correct= False );
# At trial  283 Angle= 15.395 answer is  left (correct= False );
# At trial  284 Angle= 5.921 answer is  right (correct= True );
# At trial  285 Angle= 20.132 answer is  left (correct= False );
# At trial  286 Angle= 10.658 answer is  right (correct= True );
# At trial  287 Angle= 13.026 answer is  right (correct= True );
# At trial  288 Angle= 22.500 answer is  right (correct= True );
# At trial  289 Angle= 22.500 answer is  right (correct= True );
# At trial  290 Angle= -10.658 answer is  right (correct= False );
# At trial  291 Angle= -22.500 answer is  right (correct= False );
# At trial  292 Angle= -3.553 answer is  left (correct= True );
# At trial  293 Angle= 17.763 answer is  right (correct= True );
# At trial  294 Angle= 3.553 answer is  right (correct= True );
# At trial  295 Angle= 3.553 answer is  right (correct= True );
# At trial  296 Angle= -10.658 answer is  left (correct= True );
# At trial  297 Angle= 3.553 answer is  left (correct= False );
# At trial  298 Angle= 13.026 answer is  right (correct= True );
# At trial  299 Angle= 20.132 answer is  right (correct= True );
# saving
# exiting
# 2.5572 	WARNING 	Monitor specification not found. Creating a temporary one...
# 2.5602 	WARNING 	User requested fullscreen with size [1400  800], but screen is actually [1680, 1050]. Using actual size
# 3.4484 	WARNING 	TextStim.alignVert is deprecated. Use the anchorVert attribute instead
# 3.4484 	WARNING 	TextStim.alignHoriz is deprecated. Use alignText and anchorHoriz attributes instead
# 7.8292 	WARNING 	TextStim.alignVert is deprecated. Use the anchorVert attribute instead
# 7.8292 	WARNING 	TextStim.alignHoriz is deprecated. Use alignText and anchorHoriz attributes instead
