# %% [markdown]
# ### differents $B_\theta$, differents $sf_0$

# %%
# %run 60_testing_different_sf.ipynb
# Out:
# data_folder = ../Psychopy_data/pilot/sf_0
# Overwriting tmp/60_testing_different_sf.py
#
#  Initializing
# B_thetas =  [0.20943951 0.41887902 0.62831853 0.83775804 1.04719755]
# sfs =  [0.125      0.05255603 0.02209709 0.00929068 0.00390625]

# %%
# !ipython tmp/60_testing_different_sf.py {data_folder} 5 5 18 LP
# Out:
#  Initializing
# B_thetas =  [0.20943951 0.41887902 0.62831853 0.83775804 1.04719755]
# sfs =  [0.125      0.05255603 0.02209709 0.00929068 0.00390625]
# pygame 1.9.6
# Hello from the pygame community. https://www.pygame.org/contribute.html
# 2020-05-12 15:47:38.823 Python[18699:5065004] ApplePersistenceIgnoreState: Existing state will not be touched. New state will be written to (null)
# Test started
# At trial  0 Angle= -19.853 answer is  left (correct= True );
# At trial  1 Angle= -11.912 answer is  left (correct= True );
# At trial  2 Angle= -22.500 answer is  left (correct= True );
# At trial  3 Angle= -9.265 answer is  right (correct= False );
# At trial  4 Angle= 6.618 answer is  right (correct= True );
# At trial  5 Angle= 3.971 answer is  right (correct= True );
# At trial  6 Angle= 1.324 answer is  left (correct= False );
# At trial  7 Angle= 9.265 answer is  right (correct= True );
# At trial  8 Angle= -9.265 answer is  left (correct= True );
# ...
