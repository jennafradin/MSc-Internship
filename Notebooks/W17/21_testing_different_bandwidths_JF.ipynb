# %% [markdown]
# ### differents $B_\theta$, petits $\theta$, differents $Bsf$

# %%
# %run 20_testing_different_bandwidths.ipynb
# Out:
# data_folder = ../Psychopy_data/pilot/B_theta_B_sf
# Overwriting tmp/exp.py
#
#  Initializing
# B_thetas =  [0.09817477 0.18005332 0.33021925 0.60562477 1.11072073]
# B_sfs =  [0.0625 0.125  0.25   0.5    1.    ]

# %%
# !ipython tmp/exp.py {data_folder} LP1
# Out:
#  Initializing
# B_thetas =  [0.09817477 0.18005332 0.33021925 0.60562477 1.11072073]
# B_sfs =  [0.0625 0.125  0.25   0.5    1.    ]
# pygame 1.9.6
# Hello from the pygame community. https://www.pygame.org/contribute.html
# 2020-05-05 14:15:29.084 Python[7476:1851662] ApplePersistenceIgnoreState: Existing state will not be touched. New state will be written to (null)
# Test started
# At trial  0 Angle= -5.431 answer is  left (correct= True );
# At trial  1 Angle= 16.293 answer is  right (correct= True );
# At trial  2 Angle= -6.983 answer is  left (correct= True );
# At trial  3 Angle= -14.741 answer is  left (correct= True );
# At trial  4 Angle= -16.293 answer is  left (correct= True );
# At trial  5 Angle= -17.845 answer is  left (correct= True );
# At trial  6 Angle= 5.431 answer is  right (correct= True );
# At trial  7 Angle= -19.397 answer is  left (correct= True );
# At trial  8 Angle= 2.328 answer is  right (correct= True );
# ...

# %%
# %whos
# Out:
# Variable         Type       Data/Info
# -------------------------------------
# N_B_sf           int        5
# N_B_thetas       int        3
# N_total_trials   int        60
# N_trial          int        4
# conditions       ndarray    60: 60 elems, type `int64`, 480 bytes
# data_folder      str        ../Psychopy_data/pilot/B_theta_B_sf
# ind              ndarray    60: 60 elems, type `int64`, 480 bytes
# np               module     <module 'numpy' from '/us<...>kages/numpy/__init__.py'>
# os               module     <module 'os' from '/usr/l<...>3.7/lib/python3.7/os.py'>
# seed             int        42
# theta_max        int        20
# thetas           ndarray    60: 60 elems, type `float64`, 480 bytes
