# %% [markdown]
#  #### Refaire l'expèrience en utilisant des petits $B_\theta$ (<15°)

# %%
import numpy as np
import MotionClouds as mc
import matplotlib.pyplot as plt
import os
import imageio
import random
from psychopy import visual, core, event, gui, data
import MotionClouds as MC
# Out:
# pygame 1.9.6
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
exp_name = "Perception de l'orientation"
exp_info = {'participant':''}
subj_info = gui.DlgFromDict(dictionary=exp_info, title=exp_name)
exp_info['exp_name']=exp_name

# %%
downscale = 1
fig_width = 21
fx, fy, ft = mc.get_grids(mc.N_X/downscale, mc.N_Y/downscale, 1)

# %%
from psychopy import visual, core, event
import MotionClouds as MC

test_length = 150  # number of trials
fixation_length = .5  # length of fixation, in second
stim1_length = 0.25  # length of first stim, in second
stim2_length = 0.25  # length of the second stim, in second 

fullscr = False

fullscr = True

# %%
def generate_random_cloud(theta, B_theta, downscale = 1):
    fx, fy, ft = mc.get_grids(mc.N_X/downscale, mc.N_Y/downscale, 1)
    mc_i = mc.envelope_gabor(fx, fy, ft, V_X=0., V_Y=0.,
                             B_V=0, theta=theta, B_theta=B_theta)
    im = mc.random_cloud(mc_i)
    im = (mc.rectif(im) * 255).astype('uint8')
    fname = 'tmp/%s_%s.png' % (theta, B_theta)
    imageio.imwrite(fname, im[:, :, 0])
    return fname

# %%
win = visual.Window(fullscr=fullscr, color=[0,0,0], winType='pygame', monitor='testMonitor', units='height')
mouse = event.Mouse(visible=False)

fixation = visual.ShapeStim(vertices='cross', win=win, size=0.05, pos=[0, 0], fillColor='black', units='height')
fixation.autolog = False

MC1 = generate_random_cloud(np.pi/2, B_theta=np.pi/2)
bitmap1 = visual.ImageStim(win, MC1, mask='gauss', size=0.8, units='height')
bitmap1.autolog = False 

msg = visual.TextStim(win, text='?', color='black')

import time
start_time = time.time()
print("Test started")


ans_list = []
N_B_thetas = 3
B_thetas = np.pi*np.logspace(-7, -3.5, N_B_thetas, base=2)
    
std_theta = np.pi/6
for trial in range(test_length):
    clock = core.Clock()
    fixation.draw()
    win.flip()
    
    theta = std_theta * np.random.randn()

    # MC generation
    B_theta = B_thetas[random.randint(0, N_B_thetas-1)]

    MC1 = generate_random_cloud(np.pi/2-theta, B_theta=B_theta) 
    bitmap1.setImage(MC1)

    # Times the trial
    while clock.getTime() < fixation_length + stim1_length + stim2_length:
        if 0.0 <= clock.getTime() < fixation_length:  # fixation
            fixation.draw()
        if fixation_length + 0.01 <= clock.getTime() < fixation_length + stim1_length: 
            bitmap1.draw()
            win.flip()
        if fixation_length + stim1_length <= clock.getTime() < fixation_length + stim1_length + stim2_length:
            msg.draw()
            

   
    win.flip()

    while True:
        ans = event.waitKeys()

        if ans == ['escape', 'q']:
            win.close()
            core.quit()
        elif ans[0] in ['left', 'right']:
            correct = (np.sign(theta) > 0) and (ans[0]=='right')
            print('At trial ', trial, 'Angle=', '%3.3f' % (theta*180/np.pi), 'answer is ',
                ans[0], '(correct=', correct, '); bandwidth=', '%.3f' % (B_theta*180/np.pi))    
            break

    # Output shape per trial is : trial number, shift direction, answered shift and b_theta
    ans_list.append([trial, theta, ans[0], B_theta])

win.close()
# Out:
# Test started
# At trial  0 Angle= 15.347 answer is  right (correct= True ); bandwidth= 4.730
# At trial  1 Angle= -9.692 answer is  left (correct= False ); bandwidth= 4.730
# At trial  2 Angle= 16.728 answer is  right (correct= True ); bandwidth= 4.730
# At trial  3 Angle= 54.599 answer is  right (correct= True ); bandwidth= 15.910
# At trial  4 Angle= 15.841 answer is  right (correct= True ); bandwidth= 1.406
# At trial  5 Angle= 53.322 answer is  right (correct= True ); bandwidth= 15.910
# At trial  6 Angle= 5.941 answer is  right (correct= True ); bandwidth= 1.406
# At trial  7 Angle= -19.349 answer is  left (correct= False ); bandwidth= 4.730
# At trial  8 Angle= -23.547 answer is  left (correct= False ); bandwidth= 1.406
# At trial  9 Angle= -34.449 answer is  left (correct= False ); bandwidth= 1.406
# At trial  10 Angle= 41.837 answer is  right (correct= True ); bandwidth= 4.730
# At trial  11 Angle= -28.374 answer is  left (correct= False ); bandwidth= 4.730
# At trial  12 Angle= 5.275 answer is  right (correct= True ); bandwidth= 4.730
# At trial  13 Angle= 4.877 answer is  right (correct= True ); bandwidth= 15.910
# At trial  14 Angle= -39.794 answer is  left (correct= False ); bandwidth= 15.910
# At trial  15 Angle= 39.272 answer is  right (correct= True ); bandwidth= 1.406
# At trial  16 Angle= 12.432 answer is  right (correct= True ); bandwidth= 4.730
# At trial  17 Angle= -17.370 answer is  left (correct= False ); bandwidth= 1.406
# At trial  18 Angle= 25.411 answer is  right (correct= True ); bandwidth= 1.406
# At trial  19 Angle= -44.339 answer is  left (correct= False ); bandwidth= 15.910
# At trial  20 Angle= -14.300 answer is  left (correct= False ); bandwidth= 15.910
# At trial  21 Angle= 39.814 answer is  right (correct= True ); bandwidth= 1.406
# At trial  22 Angle= 12.740 answer is  right (correct= True ); bandwidth= 4.730
# At trial  23 Angle= -5.080 answer is  left (correct= False ); bandwidth= 1.406
# At trial  24 Angle= 38.289 answer is  right (correct= True ); bandwidth= 1.406
# At trial  25 Angle= -39.068 answer is  left (correct= False ); bandwidth= 4.730
# At trial  26 Angle= 13.949 answer is  right (correct= True ); bandwidth= 4.730
# At trial  27 Angle= 18.860 answer is  right (correct= True ); bandwidth= 4.730
# At trial  28 Angle= 15.286 answer is  right (correct= True ); bandwidth= 4.730
# At trial  29 Angle= -21.420 answer is  left (correct= False ); bandwidth= 15.910
# At trial  30 Angle= -16.192 answer is  left (correct= False ); bandwidth= 1.406
# At trial  31 Angle= 11.312 answer is  right (correct= True ); bandwidth= 15.910
# At trial  32 Angle= 31.348 answer is  right (correct= True ); bandwidth= 15.910
# At trial  33 Angle= -0.494 answer is  left (correct= False ); bandwidth= 4.730
# At trial  34 Angle= -41.734 answer is  left (correct= False ); bandwidth= 1.406
# At trial  35 Angle= 15.393 answer is  right (correct= True ); bandwidth= 4.730
# At trial  36 Angle= -73.954 answer is  left (correct= False ); bandwidth= 1.406
# At trial  37 Angle= 22.712 answer is  right (correct= True ); bandwidth= 15.910
# At trial  38 Angle= -28.853 answer is  left (correct= False ); bandwidth= 15.910
# At trial  39 Angle= -3.617 answer is  left (correct= False ); bandwidth= 4.730
# At trial  40 Angle= -51.562 answer is  left (correct= False ); bandwidth= 15.910
# At trial  41 Angle= 31.738 answer is  right (correct= True ); bandwidth= 4.730
# At trial  42 Angle= 25.678 answer is  right (correct= True ); bandwidth= 15.910
# At trial  43 Angle= -1.316 answer is  right (correct= False ); bandwidth= 1.406
# At trial  44 Angle= -19.483 answer is  left (correct= False ); bandwidth= 15.910
# At trial  45 Angle= 43.890 answer is  right (correct= True ); bandwidth= 4.730
# At trial  46 Angle= -2.060 answer is  left (correct= False ); bandwidth= 15.910
# At trial  47 Angle= -3.623 answer is  left (correct= False ); bandwidth= 15.910
# At trial  48 Angle= -12.017 answer is  left (correct= False ); bandwidth= 1.406
# At trial  49 Angle= -17.457 answer is  left (correct= False ); bandwidth= 1.406
# At trial  50 Angle= 5.146 answer is  right (correct= True ); bandwidth= 4.730
# At trial  51 Angle= 14.467 answer is  right (correct= True ); bandwidth= 15.910
# At trial  52 Angle= -17.106 answer is  left (correct= False ); bandwidth= 15.910
# At trial  53 Angle= 13.587 answer is  right (correct= True ); bandwidth= 15.910
# At trial  54 Angle= 5.205 answer is  right (correct= True ); bandwidth= 4.730
# At trial  55 Angle= -6.251 answer is  left (correct= False ); bandwidth= 15.910
# At trial  56 Angle= -3.209 answer is  left (correct= False ); bandwidth= 1.406
# At trial  57 Angle= 13.374 answer is  right (correct= True ); bandwidth= 15.910
# At trial  58 Angle= 2.300 answer is  right (correct= True ); bandwidth= 4.730
# At trial  59 Angle= 0.354 answer is  right (correct= True ); bandwidth= 15.910
# At trial  60 Angle= 11.893 answer is  right (correct= True ); bandwidth= 4.730
# At trial  61 Angle= 70.794 answer is  right (correct= True ); bandwidth= 15.910
# At trial  62 Angle= -8.153 answer is  left (correct= False ); bandwidth= 15.910
# At trial  63 Angle= -30.946 answer is  left (correct= False ); bandwidth= 1.406
# At trial  64 Angle= 52.604 answer is  right (correct= True ); bandwidth= 4.730
# At trial  65 Angle= -15.829 answer is  left (correct= False ); bandwidth= 15.910
# At trial  66 Angle= -2.507 answer is  left (correct= False ); bandwidth= 15.910
# At trial  67 Angle= -64.271 answer is  left (correct= False ); bandwidth= 1.406
# At trial  68 Angle= -0.992 answer is  right (correct= False ); bandwidth= 15.910
# At trial  69 Angle= 52.379 answer is  right (correct= True ); bandwidth= 1.406
# At trial  70 Angle= -17.015 answer is  left (correct= False ); bandwidth= 1.406
# At trial  71 Angle= -9.524 answer is  left (correct= False ); bandwidth= 1.406
# At trial  72 Angle= -15.286 answer is  left (correct= False ); bandwidth= 1.406
# At trial  73 Angle= -48.010 answer is  left (correct= False ); bandwidth= 1.406
# At trial  74 Angle= 24.821 answer is  right (correct= True ); bandwidth= 15.910
# At trial  75 Angle= 3.952 answer is  right (correct= True ); bandwidth= 4.730
# At trial  76 Angle= -14.940 answer is  left (correct= False ); bandwidth= 4.730
# At trial  77 Angle= -18.638 answer is  left (correct= False ); bandwidth= 1.406
# At trial  78 Angle= 33.169 answer is  right (correct= True ); bandwidth= 1.406
# At trial  79 Angle= -2.420 answer is  left (correct= False ); bandwidth= 15.910
# At trial  80 Angle= 9.196 answer is  right (correct= True ); bandwidth= 4.730
# At trial  81 Angle= 0.252 answer is  right (correct= True ); bandwidth= 1.406
# At trial  82 Angle= 14.920 answer is  right (correct= True ); bandwidth= 15.910
# At trial  83 Angle= -3.562 answer is  left (correct= False ); bandwidth= 4.730
# At trial  84 Angle= 32.616 answer is  right (correct= True ); bandwidth= 1.406
# At trial  85 Angle= 72.500 answer is  right (correct= True ); bandwidth= 4.730
# At trial  86 Angle= 11.350 answer is  right (correct= True ); bandwidth= 4.730
# At trial  87 Angle= -8.549 answer is  left (correct= False ); bandwidth= 15.910
# At trial  88 Angle= -9.422 answer is  left (correct= False ); bandwidth= 4.730
# At trial  89 Angle= 12.155 answer is  right (correct= True ); bandwidth= 1.406
# At trial  90 Angle= 53.102 answer is  right (correct= True ); bandwidth= 1.406
# At trial  91 Angle= -49.113 answer is  left (correct= False ); bandwidth= 4.730
# At trial  92 Angle= -17.126 answer is  left (correct= False ); bandwidth= 4.730
# At trial  93 Angle= 24.701 answer is  right (correct= True ); bandwidth= 15.910
# At trial  94 Angle= -27.137 answer is  left (correct= False ); bandwidth= 1.406
# At trial  95 Angle= 48.043 answer is  right (correct= True ); bandwidth= 15.910
# At trial  96 Angle= 24.303 answer is  right (correct= True ); bandwidth= 15.910
# At trial  97 Angle= -4.014 answer is  left (correct= False ); bandwidth= 15.910
# At trial  98 Angle= -8.839 answer is  left (correct= False ); bandwidth= 15.910
# At trial  99 Angle= -10.579 answer is  left (correct= False ); bandwidth= 4.730
# At trial  100 Angle= -0.080 answer is  right (correct= False ); bandwidth= 4.730
# At trial  101 Angle= -32.039 answer is  left (correct= False ); bandwidth= 1.406
# At trial  102 Angle= 20.553 answer is  left (correct= False ); bandwidth= 1.406
# At trial  103 Angle= 1.127 answer is  right (correct= True ); bandwidth= 15.910
# At trial  104 Angle= 22.739 answer is  right (correct= True ); bandwidth= 4.730
# At trial  105 Angle= -26.847 answer is  left (correct= False ); bandwidth= 15.910
# At trial  106 Angle= 8.313 answer is  right (correct= True ); bandwidth= 15.910
# At trial  107 Angle= 85.130 answer is  right (correct= True ); bandwidth= 15.910
# At trial  108 Angle= 50.140 answer is  right (correct= True ); bandwidth= 1.406
# At trial  109 Angle= 6.601 answer is  right (correct= True ); bandwidth= 1.406
# At trial  110 Angle= 27.693 answer is  right (correct= True ); bandwidth= 1.406
# At trial  111 Angle= 47.374 answer is  right (correct= True ); bandwidth= 15.910
# At trial  112 Angle= -29.770 answer is  left (correct= False ); bandwidth= 1.406
# At trial  113 Angle= -43.534 answer is  left (correct= False ); bandwidth= 1.406
# At trial  114 Angle= -5.367 answer is  left (correct= False ); bandwidth= 15.910
# At trial  115 Angle= -37.238 answer is  left (correct= False ); bandwidth= 4.730
# At trial  116 Angle= 66.422 answer is  right (correct= True ); bandwidth= 4.730
# At trial  117 Angle= -28.459 answer is  left (correct= False ); bandwidth= 4.730
# At trial  118 Angle= 45.547 answer is  right (correct= True ); bandwidth= 15.910
# At trial  119 Angle= 3.506 answer is  right (correct= True ); bandwidth= 15.910
# At trial  120 Angle= -15.926 answer is  left (correct= False ); bandwidth= 15.910
# At trial  121 Angle= 57.103 answer is  right (correct= True ); bandwidth= 4.730
# At trial  122 Angle= -25.758 answer is  left (correct= False ); bandwidth= 15.910
# At trial  123 Angle= -29.354 answer is  left (correct= False ); bandwidth= 4.730
# At trial  124 Angle= -33.719 answer is  left (correct= False ); bandwidth= 1.406
# At trial  125 Angle= -37.657 answer is  left (correct= False ); bandwidth= 15.910
# At trial  126 Angle= -26.760 answer is  left (correct= False ); bandwidth= 4.730
# At trial  127 Angle= -7.840 answer is  left (correct= False ); bandwidth= 1.406
# At trial  128 Angle= 21.492 answer is  right (correct= True ); bandwidth= 4.730
# At trial  129 Angle= 9.019 answer is  right (correct= True ); bandwidth= 4.730
# At trial  130 Angle= 45.102 answer is  right (correct= True ); bandwidth= 15.910
# At trial  131 Angle= 2.601 answer is  right (correct= True ); bandwidth= 15.910
# At trial  132 Angle= 11.902 answer is  right (correct= True ); bandwidth= 1.406
# At trial  133 Angle= -16.365 answer is  left (correct= False ); bandwidth= 15.910
# At trial  134 Angle= 8.448 answer is  right (correct= True ); bandwidth= 4.730
# At trial  135 Angle= -13.014 answer is  right (correct= False ); bandwidth= 1.406
# At trial  136 Angle= 12.490 answer is  right (correct= True ); bandwidth= 1.406
# At trial  137 Angle= 24.636 answer is  right (correct= True ); bandwidth= 1.406
# At trial  138 Angle= -37.407 answer is  left (correct= False ); bandwidth= 4.730
# At trial  139 Angle= -20.199 answer is  left (correct= False ); bandwidth= 1.406
# At trial  140 Angle= -1.291 answer is  left (correct= False ); bandwidth= 4.730
# At trial  141 Angle= 54.057 answer is  right (correct= True ); bandwidth= 4.730
# At trial  142 Angle= 18.732 answer is  right (correct= True ); bandwidth= 1.406
# At trial  143 Angle= 28.488 answer is  right (correct= True ); bandwidth= 1.406
# At trial  144 Angle= 20.338 answer is  right (correct= True ); bandwidth= 15.910
# At trial  145 Angle= -37.501 answer is  left (correct= False ); bandwidth= 4.730
# At trial  146 Angle= -7.519 answer is  left (correct= False ); bandwidth= 4.730
# At trial  147 Angle= -5.571 answer is  left (correct= False ); bandwidth= 4.730
# At trial  148 Angle= -22.525 answer is  left (correct= False ); bandwidth= 4.730
# At trial  149 Angle= 23.989 answer is  right (correct= True ); bandwidth= 1.406
# 107.9114 	WARNING 	User requested fullscreen with size [800 600], but screen is actually [1366, 768]. Using actual size

# %%
import pickle
pickle.dump(ans_list, open('Psychophys_discrim_%s.p' % exp_info['participant'], 'wb'))
#on sauve nos superbes données

# %%
import pickle
import matplotlib.pyplot as plt

subj_name_list =  ['JF4','JF5','JF6']

                
subj_data_list = []

for subject in subj_name_list :
    x = pickle.load(open(r'C:\Users\Utilisateur\Documents\psychophysics_data\pilote\B_theta\Psychophys_discrim_%s.p'%subject, 'rb'))

    #pickle.load,charge le contenu du fichier B_theta dans x
    
    subj_data_list.append(x)

# %%
from sklearn.linear_model import LogisticRegression
import numpy as np
from matplotlib.pyplot import cm

x_values = np.linspace(-50, 50, 100)
x_plot = np.reshape(x_values, (100,1))
lr_kwargs = dict(solver='liblinear', C = 3, max_iter=1000, penalty='l2', class_weight = {1 : 1 , 0 : 1})


b_thetas_list = []
for x in subj_data_list[0] :
    b_thetas_list.append(x[3]*180/np.pi)
b_thetas_list = sorted(set(b_thetas_list))

coef_list = []

for num, subj_data in enumerate(subj_data_list) :
    color = iter(cm.Dark2(np.linspace(.5, 1,5)))
    plt.figure(figsize = (8,6)) 
    for ibtheta, b_theta in enumerate(b_thetas_list):
        X = []
        y = []

        for i in subj_data :
            if i[3]*180/np.pi == b_theta :
                X.append(i[1]*180/np.pi)
                if  i[2] == 'right':  
                        y.append(1)
                else :
                        y.append(0)
      
        X = np.asarray(X)
        X = X[:,np.newaxis]
        col = next(color)
    
        lgs = LogisticRegression(**lr_kwargs)
        try :
            lgs.fit(X, y)
            coef_list.append((b_theta,lgs.coef_[0][0]))
        
            y_values = lgs.predict_proba(x_plot)[:,1]
            plt.plot(x_values, y_values, label = r'$B_\theta$ = %3.f°' %b_theta,color = col)
            plt.scatter(X, y, s=4, color = col)
        except :
            pass
            
    plt.title('Psychometric curve - %s' % subj_name_list[num])
    plt.xlabel(r'$\theta$')
    plt.yticks([0.,1.],['No', 'Yes'])
    plt.legend(loc = (0.03, 0.52)) 
    plt.show
