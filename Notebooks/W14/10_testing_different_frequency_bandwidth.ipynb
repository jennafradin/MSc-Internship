# %% [markdown]
#  #### Refaire l'experience en utilisant des petits $B_\theta$ (<15°)

# %%
import numpy as np
import MotionClouds as mc
import matplotlib.pyplot as plt
import os
import imageio
import random
from psychopy import visual, core, event, gui, data
import MotionClouds as MC
import pygame
# Out:
# pygame 1.9.6
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
exp_name = "Perception de l'orientation"
exp_info = {'participant':''}
subj_info = gui.DlgFromDict(dictionary=exp_info, title=exp_name)
exp_info['exp_name'] = exp_name
data_folder = os.path.join('..', 'Psychopy_data', 'pilot', 'mouse_motion','json')
data_folder
# Out:
# '../Psychopy_data/pilot/mouse_motion/json'

# %%
# %mkdir -p {data_folder}

# %%
downscale = 1
fig_width = 21
fx, fy, ft = mc.get_grids(mc.N_X/downscale, mc.N_Y/downscale, 1)

# %%
test_length = 150     # number of trials
fixation_length = .5  # length of fixation, in second
stim1_length = 0.25   # length of first stim, in second
stim2_length = 0.25   # length of the second stim, in second 

fullscr = False

fullscr = True

# %%
def generate_random_cloud(theta, B_theta, B_sf, downscale = 1):
    fx, fy, ft = mc.get_grids(mc.N_X/downscale, mc.N_Y/downscale, 1)
    mc_i = mc.envelope_gabor(fx, fy, ft, V_X=0., V_Y=0.,
                             B_V=0, theta=theta, B_theta=B_theta)
    im = mc.random_cloud(mc_i)
    im = (mc.rectif(im) * 255).astype('uint8')
    fname = 'tmp/%s_%s.png' % (theta, B_theta)
    imageio.imwrite(fname, im[:, :, 0])
    return fname

# %%
# %mkdir -p tmp

# %%
#win = visual.Window([1400,800],fullscr=fullscr, color=[0,0,0], winType='pygame', monitor='testMonitor', units='height')
win = visual.Window([1400, 800], fullscr=fullscr, color=[0, 0, 0])


mouse = event.Mouse(newPos=(0, 0), visible=False)
x0, y0 = mouse.getPos()
event.clearEvents()
instructions = """
At each trial you see one textured image, report the 
orientation you perceive.

Move the mouse to the right if it is clock-wise of the vertical,
move the mouse to the left if it is counter clock-wise of the vertical.

Move the mouse to begin the experiment.
"""
msg = visual.TextStim(win, text=instructions, alignHoriz='center', alignVert='center', color='black')
msg.draw()
win.flip()
while not mouse.mouseMoved(distance=.05): 
    event.clearEvents()
    
fixation = visual.ShapeStim(vertices='cross', win=win, size=0.05, pos=[0, 0], fillColor='black', units='height')
fixation.autolog = False

MC1 = generate_random_cloud(np.pi/2, B_theta=np.pi/2, B_sf=0.1)
bitmap1 = visual.ImageStim(win, MC1, mask='gauss', size=0.8, units='height')
bitmap1.autolog = False 

msg = visual.TextStim(win, text='?', color='black')

import time
start_time = time.time()
print("Test started")


ans_list = []
N_B_thetas = 5 
N_B_Bsf = 5
B_thetas = np.pi*np.logspace(-7, -3.5, N_B_thetas, base=2)
B_sfs = np.logspace(-4,0.,N_B_Bsf,base=2)
    
std_theta = np.pi/6
for trial in range(test_length):
    clock = core.Clock()
    fixation.draw()
    win.flip()
    
    theta = std_theta * np.random.randn()
    
    # MC generation
    B_theta = B_thetas[random.randint(0, N_B_thetas-1)]
    B_sf = B_sfs[random.randint(0, N_B_Bsf-1)]
    MC1 = generate_random_cloud(np.pi/2-theta, B_theta=B_theta, B_sf=B_sf) 
    bitmap1.setImage(MC1)

    # Times the trial
    while clock.getTime() < fixation_length + stim1_length + stim2_length:
        if 0.0 <= clock.getTime() < fixation_length:  # fixation
            fixation.draw()
        if fixation_length + 0.01 <= clock.getTime() < fixation_length + stim1_length: 
            bitmap1.draw()
            win.flip()
        if fixation_length + stim1_length <= clock.getTime() < fixation_length + stim1_length + stim2_length:
            msg.draw()
            
    win.flip()

    mouse.setPos(newPos=(0, 0))
    x0, y0 = mouse.getPos()
    event.clearEvents()

    while not mouse.mouseMoved(distance=.05): 
        # this creates a never-ending loop
        # until we move the mouse
        event.clearEvents()

    x, y = mouse.getPos()
    if x < 0:
        answer = 'left'
    else: #elif x > 0:
        answer = 'right'
        if x == 0: print('this should not happen 😤')
    event.clearEvents() 
    # print('answer', answer, ', x', x)

    ans = event.getKeys()   

    if ans == ['escape', 'q']:
        win.close()
        core.quit()

    correct = ((theta > 0) and answer == 'right') or ((theta < 0) and answer == 'left')
    print('At trial ', trial, 'Angle=', '%3.3f' % (theta*180/np.pi), 'answer is ',  answer, '(correct=', correct, '); bandwidth=', '%.3f' % (B_theta*180/np.pi),'B_sf=', B_sf)   
       
    # Output shape per trial is : trial number, shift direction, answered shift and b_theta
    ans_list.append([trial, theta, answer, B_theta, B_sf])

win.close()
# Out:
# Test started
# At trial  0 Angle= 31.915 answer is  right (correct= True ); bandwidth= 2.579 B_sf= 0.125
# At trial  1 Angle= 0.392 answer is  left (correct= False ); bandwidth= 8.675 B_sf= 1.0
# At trial  2 Angle= -59.607 answer is  left (correct= True ); bandwidth= 1.406 B_sf= 0.5
# At trial  3 Angle= -14.853 answer is  left (correct= True ); bandwidth= 4.730 B_sf= 1.0
# At trial  4 Angle= 38.416 answer is  right (correct= True ); bandwidth= 4.730 B_sf= 0.0625
# At trial  5 Angle= 33.060 answer is  right (correct= True ); bandwidth= 1.406 B_sf= 0.5
# At trial  6 Angle= 7.635 answer is  right (correct= True ); bandwidth= 8.675 B_sf= 0.125
# At trial  7 Angle= 39.933 answer is  right (correct= True ); bandwidth= 8.675 B_sf= 0.5
# At trial  8 Angle= 4.841 answer is  right (correct= True ); bandwidth= 15.910 B_sf= 1.0
# At trial  9 Angle= -19.118 answer is  left (correct= True ); bandwidth= 8.675 B_sf= 1.0
# At trial  10 Angle= -5.835 answer is  left (correct= True ); bandwidth= 1.406 B_sf= 0.125
# At trial  11 Angle= -13.490 answer is  left (correct= True ); bandwidth= 2.579 B_sf= 1.0
# At trial  12 Angle= -16.892 answer is  left (correct= True ); bandwidth= 4.730 B_sf= 0.5
# At trial  13 Angle= 21.618 answer is  right (correct= True ); bandwidth= 8.675 B_sf= 0.125
# At trial  14 Angle= -28.991 answer is  left (correct= True ); bandwidth= 8.675 B_sf= 1.0
# At trial  15 Angle= 21.037 answer is  right (correct= True ); bandwidth= 1.406 B_sf= 0.5
# At trial  16 Angle= -50.407 answer is  left (correct= True ); bandwidth= 2.579 B_sf= 1.0
# At trial  17 Angle= -19.242 answer is  left (correct= True ); bandwidth= 1.406 B_sf= 1.0
# At trial  18 Angle= -31.190 answer is  left (correct= True ); bandwidth= 1.406 B_sf= 0.125
# At trial  19 Angle= 12.027 answer is  right (correct= True ); bandwidth= 2.579 B_sf= 0.5
# At trial  20 Angle= 7.522 answer is  right (correct= True ); bandwidth= 8.675 B_sf= 0.5
# At trial  21 Angle= -31.288 answer is  left (correct= True ); bandwidth= 8.675 B_sf= 1.0
# At trial  22 Angle= -9.847 answer is  left (correct= True ); bandwidth= 4.730 B_sf= 0.25
# At trial  23 Angle= -38.873 answer is  left (correct= True ); bandwidth= 4.730 B_sf= 1.0
# At trial  24 Angle= -17.725 answer is  left (correct= True ); bandwidth= 8.675 B_sf= 0.5
# At trial  25 Angle= -48.662 answer is  left (correct= True ); bandwidth= 1.406 B_sf= 0.5
# At trial  26 Angle= 43.166 answer is  right (correct= True ); bandwidth= 4.730 B_sf= 0.0625
# At trial  27 Angle= 39.047 answer is  right (correct= True ); bandwidth= 15.910 B_sf= 0.125
# At trial  28 Angle= 33.432 answer is  right (correct= True ); bandwidth= 8.675 B_sf= 0.5
# At trial  29 Angle= -53.112 answer is  left (correct= True ); bandwidth= 15.910 B_sf= 0.0625
# At trial  30 Angle= -21.892 answer is  left (correct= True ); bandwidth= 15.910 B_sf= 0.25
# At trial  31 Angle= 9.738 answer is  right (correct= True ); bandwidth= 2.579 B_sf= 1.0
# At trial  32 Angle= 37.185 answer is  right (correct= True ); bandwidth= 4.730 B_sf= 0.25
# At trial  33 Angle= 49.611 answer is  right (correct= True ); bandwidth= 8.675 B_sf= 1.0
# At trial  34 Angle= -2.912 answer is  left (correct= True ); bandwidth= 4.730 B_sf= 0.125
# At trial  35 Angle= -52.627 answer is  left (correct= True ); bandwidth= 4.730 B_sf= 0.25
# At trial  36 Angle= -31.029 answer is  left (correct= True ); bandwidth= 8.675 B_sf= 0.25
# At trial  37 Angle= 45.398 answer is  right (correct= True ); bandwidth= 4.730 B_sf= 0.0625
# At trial  38 Angle= 2.796 answer is  right (correct= True ); bandwidth= 8.675 B_sf= 0.125
# At trial  39 Angle= 14.597 answer is  right (correct= True ); bandwidth= 2.579 B_sf= 0.5
# At trial  40 Angle= -18.199 answer is  left (correct= True ); bandwidth= 15.910 B_sf= 0.125
# At trial  41 Angle= -76.087 answer is  left (correct= True ); bandwidth= 2.579 B_sf= 0.5
# At trial  42 Angle= 6.488 answer is  right (correct= True ); bandwidth= 15.910 B_sf= 0.25
# At trial  43 Angle= -23.247 answer is  left (correct= True ); bandwidth= 2.579 B_sf= 0.0625
# At trial  44 Angle= -44.036 answer is  left (correct= True ); bandwidth= 15.910 B_sf= 0.5
# At trial  45 Angle= 22.805 answer is  right (correct= True ); bandwidth= 15.910 B_sf= 1.0
# At trial  46 Angle= -5.893 answer is  left (correct= True ); bandwidth= 1.406 B_sf= 0.5
# At trial  47 Angle= -5.249 answer is  left (correct= True ); bandwidth= 8.675 B_sf= 0.125
# At trial  48 Angle= 3.104 answer is  right (correct= True ); bandwidth= 15.910 B_sf= 0.0625
# At trial  49 Angle= 12.547 answer is  right (correct= True ); bandwidth= 8.675 B_sf= 0.25
# At trial  50 Angle= -28.182 answer is  left (correct= True ); bandwidth= 4.730 B_sf= 1.0
# At trial  51 Angle= -0.887 answer is  right (correct= False ); bandwidth= 2.579 B_sf= 0.25
# At trial  52 Angle= -2.982 answer is  left (correct= True ); bandwidth= 15.910 B_sf= 0.25
# At trial  53 Angle= 21.063 answer is  right (correct= True ); bandwidth= 1.406 B_sf= 0.125
# At trial  54 Angle= -12.792 answer is  left (correct= True ); bandwidth= 15.910 B_sf= 0.5
# At trial  55 Angle= 29.952 answer is  right (correct= True ); bandwidth= 4.730 B_sf= 0.5
# At trial  56 Angle= 41.625 answer is  left (correct= False ); bandwidth= 4.730 B_sf= 0.125
# At trial  57 Angle= 13.341 answer is  right (correct= True ); bandwidth= 4.730 B_sf= 0.5
# At trial  58 Angle= -7.362 answer is  left (correct= True ); bandwidth= 15.910 B_sf= 0.0625
# At trial  59 Angle= -51.499 answer is  left (correct= True ); bandwidth= 8.675 B_sf= 0.25
# At trial  60 Angle= 31.338 answer is  right (correct= True ); bandwidth= 15.910 B_sf= 0.125
# At trial  61 Angle= 73.018 answer is  right (correct= True ); bandwidth= 2.579 B_sf= 0.5
# At trial  62 Angle= -40.991 answer is  left (correct= True ); bandwidth= 1.406 B_sf= 0.0625
# At trial  63 Angle= 13.565 answer is  right (correct= True ); bandwidth= 15.910 B_sf= 0.25
# At trial  64 Angle= -21.118 answer is  left (correct= True ); bandwidth= 4.730 B_sf= 0.0625
# At trial  65 Angle= -19.124 answer is  left (correct= True ); bandwidth= 2.579 B_sf= 0.125
# At trial  66 Angle= 45.231 answer is  right (correct= True ); bandwidth= 2.579 B_sf= 1.0
# At trial  67 Angle= -28.599 answer is  left (correct= True ); bandwidth= 2.579 B_sf= 0.5
# At trial  68 Angle= 8.110 answer is  right (correct= True ); bandwidth= 4.730 B_sf= 0.5
# At trial  69 Angle= 59.359 answer is  right (correct= True ); bandwidth= 8.675 B_sf= 0.0625
# At trial  70 Angle= -5.161 answer is  left (correct= True ); bandwidth= 15.910 B_sf= 1.0
# At trial  71 Angle= -53.462 answer is  left (correct= True ); bandwidth= 1.406 B_sf= 0.5
# At trial  72 Angle= -1.547 answer is  left (correct= True ); bandwidth= 4.730 B_sf= 1.0
# At trial  73 Angle= 7.438 answer is  right (correct= True ); bandwidth= 15.910 B_sf= 0.125
# At trial  74 Angle= -0.196 answer is  left (correct= True ); bandwidth= 4.730 B_sf= 0.25
# At trial  75 Angle= 26.490 answer is  right (correct= True ); bandwidth= 4.730 B_sf= 1.0
# At trial  76 Angle= -1.269 answer is  left (correct= True ); bandwidth= 4.730 B_sf= 0.125
# At trial  77 Angle= 83.192 answer is  right (correct= True ); bandwidth= 8.675 B_sf= 1.0
# At trial  78 Angle= -3.053 answer is  left (correct= True ); bandwidth= 1.406 B_sf= 0.125
# At trial  79 Angle= 17.756 answer is  right (correct= True ); bandwidth= 15.910 B_sf= 0.5
# At trial  80 Angle= 10.742 answer is  right (correct= True ); bandwidth= 2.579 B_sf= 0.125
# At trial  81 Angle= -49.038 answer is  left (correct= True ); bandwidth= 2.579 B_sf= 0.0625
# At trial  82 Angle= 32.695 answer is  right (correct= True ); bandwidth= 2.579 B_sf= 0.0625
# At trial  83 Angle= -7.680 answer is  left (correct= True ); bandwidth= 2.579 B_sf= 0.5
# At trial  84 Angle= -38.449 answer is  left (correct= True ); bandwidth= 2.579 B_sf= 0.5
# At trial  85 Angle= -27.513 answer is  left (correct= True ); bandwidth= 15.910 B_sf= 0.125
# At trial  86 Angle= 9.634 answer is  right (correct= True ); bandwidth= 2.579 B_sf= 0.0625
# At trial  87 Angle= 44.669 answer is  right (correct= True ); bandwidth= 15.910 B_sf= 0.5
# At trial  88 Angle= -2.556 answer is  left (correct= True ); bandwidth= 1.406 B_sf= 0.0625
# At trial  89 Angle= -33.048 answer is  left (correct= True ); bandwidth= 4.730 B_sf= 0.0625
# At trial  90 Angle= 9.500 answer is  right (correct= True ); bandwidth= 8.675 B_sf= 0.0625
# At trial  91 Angle= 54.641 answer is  right (correct= True ); bandwidth= 8.675 B_sf= 0.125
# At trial  92 Angle= 15.922 answer is  right (correct= True ); bandwidth= 15.910 B_sf= 1.0
# At trial  93 Angle= 15.862 answer is  right (correct= True ); bandwidth= 15.910 B_sf= 0.0625
# At trial  94 Angle= 14.115 answer is  right (correct= True ); bandwidth= 1.406 B_sf= 0.0625
# At trial  95 Angle= -29.256 answer is  left (correct= True ); bandwidth= 1.406 B_sf= 0.5
# At trial  96 Angle= 12.648 answer is  right (correct= True ); bandwidth= 1.406 B_sf= 0.5
# At trial  97 Angle= -34.827 answer is  left (correct= True ); bandwidth= 8.675 B_sf= 0.25
# At trial  98 Angle= 48.729 answer is  right (correct= True ); bandwidth= 2.579 B_sf= 0.0625
# At trial  99 Angle= -37.721 answer is  left (correct= True ); bandwidth= 1.406 B_sf= 0.125
# At trial  100 Angle= -16.041 answer is  left (correct= True ); bandwidth= 2.579 B_sf= 0.25
# At trial  101 Angle= -9.596 answer is  left (correct= True ); bandwidth= 15.910 B_sf= 0.0625
# At trial  102 Angle= -27.048 answer is  left (correct= True ); bandwidth= 4.730 B_sf= 0.25
# At trial  103 Angle= -44.132 answer is  left (correct= True ); bandwidth= 2.579 B_sf= 0.5
# At trial  104 Angle= 21.806 answer is  right (correct= True ); bandwidth= 8.675 B_sf= 0.5
# At trial  105 Angle= -10.745 answer is  left (correct= True ); bandwidth= 2.579 B_sf= 0.25
# At trial  106 Angle= 12.989 answer is  right (correct= True ); bandwidth= 2.579 B_sf= 1.0
# At trial  107 Angle= -12.492 answer is  left (correct= True ); bandwidth= 1.406 B_sf= 0.5
# At trial  108 Angle= -13.818 answer is  left (correct= True ); bandwidth= 1.406 B_sf= 0.125
# At trial  109 Angle= 24.503 answer is  right (correct= True ); bandwidth= 4.730 B_sf= 0.5
# At trial  110 Angle= -3.757 answer is  left (correct= True ); bandwidth= 4.730 B_sf= 1.0
# At trial  111 Angle= 27.548 answer is  right (correct= True ); bandwidth= 2.579 B_sf= 1.0
# At trial  112 Angle= -8.163 answer is  left (correct= True ); bandwidth= 15.910 B_sf= 1.0
# At trial  113 Angle= 24.253 answer is  right (correct= True ); bandwidth= 8.675 B_sf= 0.0625
# At trial  114 Angle= 9.965 answer is  right (correct= True ); bandwidth= 2.579 B_sf= 0.25
# At trial  115 Angle= 25.657 answer is  right (correct= True ); bandwidth= 4.730 B_sf= 0.125
# At trial  116 Angle= 11.468 answer is  right (correct= True ); bandwidth= 2.579 B_sf= 0.5
# At trial  117 Angle= 8.029 answer is  right (correct= True ); bandwidth= 15.910 B_sf= 0.125
# At trial  118 Angle= 45.860 answer is  right (correct= True ); bandwidth= 1.406 B_sf= 0.5
# At trial  119 Angle= 6.249 answer is  right (correct= True ); bandwidth= 2.579 B_sf= 0.25
# At trial  120 Angle= -12.181 answer is  left (correct= True ); bandwidth= 2.579 B_sf= 0.25
# At trial  121 Angle= -34.470 answer is  left (correct= True ); bandwidth= 8.675 B_sf= 0.25
# At trial  122 Angle= 13.547 answer is  right (correct= True ); bandwidth= 2.579 B_sf= 0.25
# At trial  123 Angle= 45.655 answer is  right (correct= True ); bandwidth= 1.406 B_sf= 0.5
# At trial  124 Angle= -39.479 answer is  left (correct= True ); bandwidth= 15.910 B_sf= 1.0
# At trial  125 Angle= -24.352 answer is  left (correct= True ); bandwidth= 2.579 B_sf= 0.25
# At trial  126 Angle= -5.960 answer is  right (correct= False ); bandwidth= 8.675 B_sf= 0.0625
# At trial  127 Angle= 4.476 answer is  right (correct= True ); bandwidth= 4.730 B_sf= 0.5
# At trial  128 Angle= -31.563 answer is  left (correct= True ); bandwidth= 2.579 B_sf= 0.5
# At trial  129 Angle= -57.011 answer is  left (correct= True ); bandwidth= 15.910 B_sf= 0.125
# At trial  130 Angle= 16.044 answer is  right (correct= True ); bandwidth= 15.910 B_sf= 0.25
# At trial  131 Angle= 19.153 answer is  right (correct= True ); bandwidth= 15.910 B_sf= 1.0
# At trial  132 Angle= -41.545 answer is  left (correct= True ); bandwidth= 15.910 B_sf= 0.25
# At trial  133 Angle= -20.145 answer is  left (correct= True ); bandwidth= 15.910 B_sf= 0.0625
# At trial  134 Angle= 7.729 answer is  right (correct= True ); bandwidth= 4.730 B_sf= 0.5
# At trial  135 Angle= 2.552 answer is  right (correct= True ); bandwidth= 2.579 B_sf= 0.125
# At trial  136 Angle= -8.545 answer is  left (correct= True ); bandwidth= 2.579 B_sf= 0.0625
# At trial  137 Angle= 16.805 answer is  right (correct= True ); bandwidth= 4.730 B_sf= 0.25
# At trial  138 Angle= 20.003 answer is  right (correct= True ); bandwidth= 1.406 B_sf= 0.125
# At trial  139 Angle= -24.331 answer is  left (correct= True ); bandwidth= 8.675 B_sf= 0.5
# At trial  140 Angle= -4.574 answer is  left (correct= True ); bandwidth= 2.579 B_sf= 0.25
# At trial  141 Angle= -17.053 answer is  left (correct= True ); bandwidth= 1.406 B_sf= 0.0625
# At trial  142 Angle= 4.967 answer is  right (correct= True ); bandwidth= 2.579 B_sf= 0.25
# At trial  143 Angle= -5.830 answer is  left (correct= True ); bandwidth= 4.730 B_sf= 0.0625
# At trial  144 Angle= -13.471 answer is  left (correct= True ); bandwidth= 15.910 B_sf= 0.125
# At trial  145 Angle= -21.216 answer is  left (correct= True ); bandwidth= 8.675 B_sf= 0.25
# At trial  146 Angle= -5.387 answer is  left (correct= True ); bandwidth= 2.579 B_sf= 0.0625
# At trial  147 Angle= 13.952 answer is  right (correct= True ); bandwidth= 8.675 B_sf= 1.0
# At trial  148 Angle= -39.215 answer is  left (correct= True ); bandwidth= 2.579 B_sf= 1.0
# At trial  149 Angle= 4.611 answer is  right (correct= True ); bandwidth= 1.406 B_sf= 1.0
# 0.6915 	WARNING 	Monitor specification not found. Creating a temporary one...
# 8.9523 	WARNING 	Monitor specification not found. Creating a temporary one...
# 8.9566 	WARNING 	User requested fullscreen with size [1400  800], but screen is actually [2560, 1440]. Using actual size
# 9.8887 	WARNING 	TextStim.alignVert is deprecated. Use the anchorVert attribute instead
# 9.8887 	WARNING 	TextStim.alignHoriz is deprecated. Use alignText and anchorHoriz attributes instead

# %% [raw]
# import pickle
# pickle.dump(ans_list, open( os.path.join(data_folder, 'Psychophys_discrim_%s.p' % exp_info['participant']), 'wb'))

# %%
import json
json.dump(ans_list, open( os.path.join(data_folder, 'Psychophys_discrim_%s.json' % exp_info['participant']), 'w', encoding="utf8"))
