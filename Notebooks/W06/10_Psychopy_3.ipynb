# %% [markdown]
#  #### Refaire l'experience en utilisant des petits $B_\theta$ (<15°)

# %%
import numpy as np
import MotionClouds as mc
import matplotlib.pyplot as plt
import os
import imageio
import random
from psychopy import visual, core, event, gui, data
import MotionClouds as MC
import pygame
# Out:
# pygame 1.9.6
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
exp_name = "Perception de l'orientation"
exp_info = {'participant':''}
subj_info = gui.DlgFromDict(dictionary=exp_info, title=exp_name)
exp_info['exp_name']=exp_name

# %%
downscale = 1
fig_width = 21
fx, fy, ft = mc.get_grids(mc.N_X/downscale, mc.N_Y/downscale, 1)

# %%
test_length = 150     # number of trials
fixation_length = .5  # length of fixation, in second
stim1_length = 0.25   # length of first stim, in second
stim2_length = 0.25   # length of the second stim, in second 

fullscr = False

fullscr = True

# %%
def generate_random_cloud(theta, B_theta, downscale = 1):
    fx, fy, ft = mc.get_grids(mc.N_X/downscale, mc.N_Y/downscale, 1)
    mc_i = mc.envelope_gabor(fx, fy, ft, V_X=0., V_Y=0.,
                             B_V=0, theta=theta, B_theta=B_theta)
    im = mc.random_cloud(mc_i)
    im = (mc.rectif(im) * 255).astype('uint8')
    fname = 'tmp/%s_%s.png' % (theta, B_theta)
    imageio.imwrite(fname, im[:, :, 0])
    return fname

# %% [raw]
# %mkdir -p tmp

# %%
win = visual.Window(fullscr=fullscr, color=[0,0,0], winType='pygame', monitor='testMonitor', units='height')
mouse = event.Mouse(visible=False)

fixation = visual.ShapeStim(vertices='cross', win=win, size=0.05, pos=[0, 0], fillColor='black', units='height')
fixation.autolog = False

MC1 = generate_random_cloud(np.pi/2, B_theta=np.pi/2)
bitmap1 = visual.ImageStim(win, MC1, mask='gauss', size=0.8, units='height')
bitmap1.autolog = False 

msg = visual.TextStim(win, text='?', color='black')

import time
start_time = time.time()
print("Test started")


ans_list = []
N_B_thetas = 3
B_thetas = np.pi*np.logspace(-7, -3.5, N_B_thetas, base=2)
    
std_theta = np.pi/6
for trial in range(test_length):
    clock = core.Clock()
    fixation.draw()
    win.flip()
    
    theta = std_theta * np.random.randn()

    # MC generation
    B_theta = B_thetas[random.randint(0, N_B_thetas-1)]

    MC1 = generate_random_cloud(np.pi/2-theta, B_theta=B_theta) 
    bitmap1.setImage(MC1)

    # Times the trial
    while clock.getTime() < fixation_length + stim1_length + stim2_length:
        if 0.0 <= clock.getTime() < fixation_length:  # fixation
            fixation.draw()
        if fixation_length + 0.01 <= clock.getTime() < fixation_length + stim1_length: 
            bitmap1.draw()
            win.flip()
        if fixation_length + stim1_length <= clock.getTime() < fixation_length + stim1_length + stim2_length:
            msg.draw()
            

   
    win.flip()

    while True:
        ans = event.getKeys()   
        mouse_pressed = pygame.mouse.get_pressed()
        
        if ans == ['escape', 'q']:
            win.close()
            core.quit()
        
        elif mouse_pressed[2]==1:
             correct = (np.sign(theta) > 0) and mouse_pressed[2]==1
             print('At trial ', trial, 'Angle=', '%3.3f' % (theta*180/np.pi), 'answer is ', 
             mouse_pressed,'(correct=', correct, ' );bandwidth=', '%.3f' % (B_theta*180/np.pi))   
             break
        
        elif mouse_pressed[0]==1:
             correct = (np.sign(theta) < 0) and mouse_pressed[0]==1
             print('At trial ', trial, 'Angle=', '%3.3f' % (theta*180/np.pi), 'answer is ', 
             mouse_pressed,'(correct=', correct, ' );bandwidth=', '%.3f' % (B_theta*180/np.pi))   
             break        
       
    # Output shape per trial is : trial number, shift direction, answered shift and b_theta
    ans_list.append([trial, theta, mouse_pressed, B_theta])

win.close()
# Out:
# Test started
# At trial  0 Angle= 11.534 answer is  (0, 0, 1) (correct= True  );bandwidth= 4.730
# At trial  1 Angle= 38.997 answer is  (0, 0, 1) (correct= True  );bandwidth= 4.730
# At trial  2 Angle= -14.817 answer is  (1, 0, 0) (correct= True  );bandwidth= 15.910
# At trial  3 Angle= 19.417 answer is  (0, 0, 1) (correct= True  );bandwidth= 15.910
# At trial  4 Angle= 34.851 answer is  (0, 0, 1) (correct= True  );bandwidth= 1.406
# At trial  5 Angle= 6.105 answer is  (0, 0, 1) (correct= True  );bandwidth= 4.730
# At trial  6 Angle= 2.059 answer is  (0, 0, 1) (correct= True  );bandwidth= 15.910
# At trial  7 Angle= 11.164 answer is  (0, 0, 1) (correct= True  );bandwidth= 4.730
# At trial  8 Angle= 38.038 answer is  (0, 0, 1) (correct= True  );bandwidth= 15.910
# At trial  9 Angle= -30.406 answer is  (1, 0, 0) (correct= True  );bandwidth= 1.406
# At trial  10 Angle= 24.495 answer is  (0, 0, 1) (correct= True  );bandwidth= 15.910
# At trial  11 Angle= 2.845 answer is  (0, 0, 1) (correct= True  );bandwidth= 1.406
# At trial  12 Angle= -25.010 answer is  (1, 0, 0) (correct= True  );bandwidth= 15.910
# At trial  13 Angle= 8.059 answer is  (0, 0, 1) (correct= True  );bandwidth= 4.730
# At trial  14 Angle= 13.483 answer is  (0, 0, 1) (correct= True  );bandwidth= 1.406
# At trial  15 Angle= 34.182 answer is  (0, 0, 1) (correct= True  );bandwidth= 1.406
# At trial  16 Angle= 25.715 answer is  (0, 0, 1) (correct= True  );bandwidth= 4.730
# At trial  17 Angle= -6.505 answer is  (1, 0, 0) (correct= True  );bandwidth= 1.406
# At trial  18 Angle= 0.720 answer is  (1, 0, 0) (correct= False  );bandwidth= 1.406
# At trial  19 Angle= -0.555 answer is  (1, 0, 0) (correct= True  );bandwidth= 4.730
# At trial  20 Angle= -29.764 answer is  (1, 0, 0) (correct= True  );bandwidth= 4.730
# At trial  21 Angle= 9.960 answer is  (0, 0, 1) (correct= True  );bandwidth= 1.406
# At trial  22 Angle= -31.825 answer is  (1, 0, 0) (correct= True  );bandwidth= 4.730
# At trial  23 Angle= -6.436 answer is  (1, 0, 0) (correct= True  );bandwidth= 15.910
# At trial  24 Angle= -12.316 answer is  (1, 0, 0) (correct= True  );bandwidth= 4.730
# At trial  25 Angle= 46.389 answer is  (0, 0, 1) (correct= True  );bandwidth= 1.406
# At trial  26 Angle= 30.496 answer is  (0, 0, 1) (correct= True  );bandwidth= 1.406
# At trial  27 Angle= 6.532 answer is  (1, 0, 0) (correct= False  );bandwidth= 4.730
# At trial  28 Angle= 12.067 answer is  (0, 0, 1) (correct= True  );bandwidth= 4.730
# At trial  29 Angle= 0.283 answer is  (1, 0, 0) (correct= False  );bandwidth= 4.730
# At trial  30 Angle= -20.340 answer is  (1, 0, 0) (correct= True  );bandwidth= 15.910
# At trial  31 Angle= 62.679 answer is  (0, 0, 1) (correct= True  );bandwidth= 4.730
# At trial  32 Angle= -1.630 answer is  (1, 0, 0) (correct= True  );bandwidth= 15.910
# At trial  33 Angle= 46.625 answer is  (0, 0, 1) (correct= True  );bandwidth= 15.910
# At trial  34 Angle= -42.552 answer is  (1, 0, 0) (correct= True  );bandwidth= 15.910
# At trial  35 Angle= -9.932 answer is  (1, 0, 0) (correct= True  );bandwidth= 1.406
# At trial  36 Angle= 14.444 answer is  (0, 0, 1) (correct= True  );bandwidth= 1.406
# At trial  37 Angle= 41.560 answer is  (0, 0, 1) (correct= True  );bandwidth= 1.406
# At trial  38 Angle= -17.657 answer is  (1, 0, 0) (correct= True  );bandwidth= 15.910
# At trial  39 Angle= -18.658 answer is  (1, 0, 0) (correct= True  );bandwidth= 1.406
# At trial  40 Angle= 7.601 answer is  (0, 0, 1) (correct= True  );bandwidth= 1.406
# At trial  41 Angle= -26.012 answer is  (1, 0, 0) (correct= True  );bandwidth= 4.730
# At trial  42 Angle= -15.360 answer is  (1, 0, 0) (correct= True  );bandwidth= 1.406
# At trial  43 Angle= 49.594 answer is  (0, 0, 1) (correct= True  );bandwidth= 4.730
# At trial  44 Angle= -28.050 answer is  (1, 0, 0) (correct= True  );bandwidth= 1.406
# At trial  45 Angle= 1.084 answer is  (1, 0, 0) (correct= False  );bandwidth= 1.406
# At trial  46 Angle= 27.500 answer is  (0, 0, 1) (correct= True  );bandwidth= 4.730
# At trial  47 Angle= -44.444 answer is  (1, 0, 0) (correct= True  );bandwidth= 4.730
# At trial  48 Angle= -15.210 answer is  (1, 0, 0) (correct= True  );bandwidth= 1.406
# At trial  49 Angle= -45.565 answer is  (1, 0, 0) (correct= True  );bandwidth= 15.910
# At trial  50 Angle= 37.806 answer is  (0, 0, 1) (correct= True  );bandwidth= 15.910
# At trial  51 Angle= 50.800 answer is  (0, 0, 1) (correct= True  );bandwidth= 15.910
# At trial  52 Angle= 16.327 answer is  (0, 0, 1) (correct= True  );bandwidth= 4.730
# At trial  53 Angle= -27.428 answer is  (1, 0, 0) (correct= True  );bandwidth= 15.910
# At trial  54 Angle= 18.288 answer is  (0, 0, 1) (correct= True  );bandwidth= 4.730
# At trial  55 Angle= 1.709 answer is  (1, 0, 0) (correct= False  );bandwidth= 1.406
# At trial  56 Angle= 20.821 answer is  (0, 0, 1) (correct= True  );bandwidth= 4.730
# At trial  57 Angle= -12.244 answer is  (1, 0, 0) (correct= True  );bandwidth= 1.406
# At trial  58 Angle= -40.220 answer is  (1, 0, 0) (correct= True  );bandwidth= 4.730
# At trial  59 Angle= 28.648 answer is  (0, 0, 1) (correct= True  );bandwidth= 15.910
# At trial  60 Angle= -39.416 answer is  (1, 0, 0) (correct= True  );bandwidth= 15.910
# At trial  61 Angle= 5.536 answer is  (0, 0, 1) (correct= True  );bandwidth= 1.406
# At trial  62 Angle= -1.345 answer is  (1, 0, 0) (correct= True  );bandwidth= 4.730
# At trial  63 Angle= 24.186 answer is  (0, 0, 1) (correct= True  );bandwidth= 15.910
# At trial  64 Angle= 14.570 answer is  (0, 0, 1) (correct= True  );bandwidth= 15.910
# At trial  65 Angle= -4.854 answer is  (1, 0, 0) (correct= True  );bandwidth= 1.406
# At trial  66 Angle= 13.686 answer is  (0, 0, 1) (correct= True  );bandwidth= 4.730
# At trial  67 Angle= 23.218 answer is  (0, 0, 1) (correct= True  );bandwidth= 4.730
# At trial  68 Angle= -16.792 answer is  (1, 0, 0) (correct= True  );bandwidth= 4.730
# At trial  69 Angle= 42.622 answer is  (0, 0, 1) (correct= True  );bandwidth= 15.910
# At trial  70 Angle= 15.957 answer is  (0, 0, 1) (correct= True  );bandwidth= 1.406
# At trial  71 Angle= -16.958 answer is  (1, 0, 0) (correct= True  );bandwidth= 1.406
# At trial  72 Angle= -30.280 answer is  (1, 0, 0) (correct= True  );bandwidth= 4.730
# At trial  73 Angle= -27.745 answer is  (1, 0, 0) (correct= True  );bandwidth= 15.910
# At trial  74 Angle= 3.229 answer is  (0, 0, 1) (correct= True  );bandwidth= 15.910
# At trial  75 Angle= -10.587 answer is  (1, 0, 0) (correct= True  );bandwidth= 15.910
# At trial  76 Angle= -9.923 answer is  (1, 0, 0) (correct= True  );bandwidth= 4.730
# At trial  77 Angle= 27.714 answer is  (0, 0, 1) (correct= True  );bandwidth= 1.406
# At trial  78 Angle= 1.379 answer is  (1, 0, 0) (correct= False  );bandwidth= 1.406
# At trial  79 Angle= -33.563 answer is  (1, 0, 0) (correct= True  );bandwidth= 4.730
# At trial  80 Angle= 38.704 answer is  (0, 0, 1) (correct= True  );bandwidth= 15.910
# At trial  81 Angle= 21.326 answer is  (0, 0, 1) (correct= True  );bandwidth= 4.730
# At trial  82 Angle= -24.589 answer is  (1, 0, 0) (correct= True  );bandwidth= 4.730
# At trial  83 Angle= 13.874 answer is  (0, 0, 1) (correct= True  );bandwidth= 15.910
# At trial  84 Angle= 47.646 answer is  (0, 0, 1) (correct= True  );bandwidth= 4.730
# At trial  85 Angle= 58.361 answer is  (0, 0, 1) (correct= True  );bandwidth= 4.730
# At trial  86 Angle= 26.471 answer is  (0, 0, 1) (correct= True  );bandwidth= 1.406
# At trial  87 Angle= 71.313 answer is  (0, 0, 1) (correct= True  );bandwidth= 4.730
# At trial  88 Angle= -31.271 answer is  (1, 0, 0) (correct= True  );bandwidth= 4.730
# At trial  89 Angle= 10.360 answer is  (0, 0, 1) (correct= True  );bandwidth= 1.406
# At trial  90 Angle= 3.189 answer is  (0, 0, 1) (correct= True  );bandwidth= 15.910
# At trial  91 Angle= -40.799 answer is  (1, 0, 0) (correct= True  );bandwidth= 1.406
# At trial  92 Angle= -4.311 answer is  (1, 0, 0) (correct= True  );bandwidth= 1.406
# At trial  93 Angle= -47.039 answer is  (1, 0, 0) (correct= True  );bandwidth= 4.730
# At trial  94 Angle= -9.932 answer is  (1, 0, 0) (correct= True  );bandwidth= 4.730
# At trial  95 Angle= 3.993 answer is  (1, 0, 0) (correct= False  );bandwidth= 15.910
# At trial  96 Angle= -19.659 answer is  (1, 0, 0) (correct= True  );bandwidth= 15.910
# At trial  97 Angle= -24.560 answer is  (1, 0, 0) (correct= True  );bandwidth= 4.730
# At trial  98 Angle= -10.110 answer is  (1, 0, 0) (correct= True  );bandwidth= 4.730
# At trial  99 Angle= 41.237 answer is  (0, 0, 1) (correct= True  );bandwidth= 1.406
# At trial  100 Angle= -24.386 answer is  (1, 0, 0) (correct= True  );bandwidth= 4.730
# At trial  101 Angle= -63.361 answer is  (1, 0, 0) (correct= True  );bandwidth= 1.406
# At trial  102 Angle= 40.818 answer is  (0, 0, 1) (correct= True  );bandwidth= 15.910
# At trial  103 Angle= -39.753 answer is  (1, 0, 0) (correct= True  );bandwidth= 15.910
# At trial  104 Angle= 90.507 answer is  (0, 0, 1) (correct= True  );bandwidth= 4.730
# At trial  105 Angle= -0.306 answer is  (1, 0, 0) (correct= True  );bandwidth= 1.406
# At trial  106 Angle= 19.916 answer is  (0, 0, 1) (correct= True  );bandwidth= 4.730
# At trial  107 Angle= -0.118 answer is  (1, 0, 0) (correct= True  );bandwidth= 4.730
# At trial  108 Angle= 28.687 answer is  (0, 0, 1) (correct= True  );bandwidth= 4.730
# At trial  109 Angle= 11.496 answer is  (0, 0, 1) (correct= True  );bandwidth= 4.730
# At trial  110 Angle= 44.724 answer is  (0, 0, 1) (correct= True  );bandwidth= 4.730
# At trial  111 Angle= 25.466 answer is  (0, 0, 1) (correct= True  );bandwidth= 15.910
# At trial  112 Angle= -7.488 answer is  (1, 0, 0) (correct= True  );bandwidth= 1.406
# At trial  113 Angle= -28.904 answer is  (1, 0, 0) (correct= True  );bandwidth= 1.406
# At trial  114 Angle= 3.585 answer is  (0, 0, 1) (correct= True  );bandwidth= 1.406
# At trial  115 Angle= -33.764 answer is  (1, 0, 0) (correct= True  );bandwidth= 15.910
# At trial  116 Angle= 50.010 answer is  (0, 0, 1) (correct= True  );bandwidth= 15.910
# At trial  117 Angle= -3.771 answer is  (1, 0, 0) (correct= True  );bandwidth= 15.910
# At trial  118 Angle= -4.890 answer is  (1, 0, 0) (correct= True  );bandwidth= 4.730
# At trial  119 Angle= -44.734 answer is  (1, 0, 0) (correct= True  );bandwidth= 15.910
# At trial  120 Angle= 2.894 answer is  (1, 0, 0) (correct= False  );bandwidth= 15.910
# At trial  121 Angle= -47.328 answer is  (1, 0, 0) (correct= True  );bandwidth= 1.406
# At trial  122 Angle= -8.926 answer is  (1, 0, 0) (correct= True  );bandwidth= 1.406
# At trial  123 Angle= 26.520 answer is  (0, 0, 1) (correct= True  );bandwidth= 15.910
# At trial  124 Angle= 19.524 answer is  (0, 0, 1) (correct= True  );bandwidth= 15.910
# At trial  125 Angle= 6.737 answer is  (0, 0, 1) (correct= True  );bandwidth= 4.730
# At trial  126 Angle= 18.873 answer is  (0, 0, 1) (correct= True  );bandwidth= 1.406
# At trial  127 Angle= 42.098 answer is  (0, 0, 1) (correct= True  );bandwidth= 4.730
# At trial  128 Angle= -32.281 answer is  (1, 0, 0) (correct= True  );bandwidth= 15.910
# At trial  129 Angle= -15.523 answer is  (1, 0, 0) (correct= True  );bandwidth= 1.406
# At trial  130 Angle= 6.077 answer is  (1, 0, 0) (correct= False  );bandwidth= 15.910
# At trial  131 Angle= 24.426 answer is  (0, 0, 1) (correct= True  );bandwidth= 4.730
# At trial  132 Angle= 5.943 answer is  (0, 0, 1) (correct= True  );bandwidth= 1.406
# At trial  133 Angle= -33.247 answer is  (1, 0, 0) (correct= True  );bandwidth= 15.910
# At trial  134 Angle= 28.353 answer is  (0, 0, 1) (correct= True  );bandwidth= 4.730
# At trial  135 Angle= 70.857 answer is  (0, 0, 1) (correct= True  );bandwidth= 1.406
# At trial  136 Angle= -45.361 answer is  (1, 0, 0) (correct= True  );bandwidth= 4.730
# At trial  137 Angle= 51.343 answer is  (0, 0, 1) (correct= True  );bandwidth= 15.910
# At trial  138 Angle= 47.252 answer is  (0, 0, 1) (correct= True  );bandwidth= 1.406
# At trial  139 Angle= 10.210 answer is  (0, 0, 1) (correct= True  );bandwidth= 15.910
# At trial  140 Angle= -14.462 answer is  (1, 0, 0) (correct= True  );bandwidth= 1.406
# At trial  141 Angle= -1.598 answer is  (1, 0, 0) (correct= True  );bandwidth= 1.406
# At trial  142 Angle= -12.110 answer is  (1, 0, 0) (correct= True  );bandwidth= 1.406
# At trial  143 Angle= -1.724 answer is  (1, 0, 0) (correct= True  );bandwidth= 4.730
# At trial  144 Angle= -41.816 answer is  (1, 0, 0) (correct= True  );bandwidth= 1.406
# At trial  145 Angle= 12.565 answer is  (0, 0, 1) (correct= True  );bandwidth= 1.406
# At trial  146 Angle= -2.677 answer is  (1, 0, 0) (correct= True  );bandwidth= 15.910
# At trial  147 Angle= -23.261 answer is  (1, 0, 0) (correct= True  );bandwidth= 1.406
# At trial  148 Angle= -19.525 answer is  (1, 0, 0) (correct= True  );bandwidth= 15.910
# At trial  149 Angle= -53.935 answer is  (1, 0, 0) (correct= True  );bandwidth= 15.910
# 11.9762 	WARNING 	User requested fullscreen with size [800 600], but screen is actually [1366, 768]. Using actual size

# %%
import pickle
pickle.dump(ans_list, open('Psychophys_discrim_%s.p' % exp_info['participant'], 'wb'))

# %%
import pickle
import matplotlib.pyplot as plt

subj_name_list =  ['JF12'] #changer et mettre le nom de nouveaux participants

                
subj_data_list = []

for subject in subj_name_list :
    x = pickle.load(open(r'C:\Users\Utilisateur\Documents\github\Msc-Internship\Msc-Internship\Notebooks\W06\Psychophys_discrim_%s.p'%subject, 'rb'))
     #changer et mettre le path du fichier où se trouve les psychophysic data
    subj_data_list.append(x)

# %%
from sklearn.linear_model import LogisticRegression
import numpy as np
from matplotlib.pyplot import cm

x_values = np.linspace(-50, 50, 100)
x_plot = np.reshape(x_values, (100,1))
lr_kwargs = dict(solver='liblinear', C = 3, max_iter=1000, penalty='l2', class_weight = {1 : 1 , 0 : 1})


b_thetas_list = []
for x in subj_data_list[0] :
    b_thetas_list.append(x[3]*180/np.pi)
b_thetas_list = sorted(set(b_thetas_list))

coef_list = []

for num, subj_data in enumerate(subj_data_list) :
    color = iter(cm.Dark2(np.linspace(.5, 1,5)))
    plt.figure(figsize = (8,6)) 
    for ibtheta, b_theta in enumerate(b_thetas_list):
        X = []
        y = []

        for i in subj_data :
            if i[3]*180/np.pi == b_theta :
                X.append(i[1]*180/np.pi)
                if  i[2] == (0,0,1):  
                        y.append(1)
                else :
                        y.append(0)
                
                
        X = np.asarray(X)
        X = X[:,np.newaxis]
        col = next(color)
    
        lgs = LogisticRegression(**lr_kwargs)
        try :
            lgs.fit(X, y)
            coef_list.append((b_theta,lgs.coef_[0][0]))
        
            y_values = lgs.predict_proba(x_plot)[:,1]
            plt.plot(x_values, y_values, label = r'$B_\theta$ = %3.f°' %b_theta,color = col)
            plt.scatter(X, y, s=4, color = col)
        except :
            pass
            
    plt.title('Psychometric curve - %s' % subj_name_list[num])
    plt.xlabel(r'$\theta$')
    plt.yticks([0.,1.],['No', 'Yes'])
    plt.legend(loc = (0.03, 0.52)) 
    plt.show
